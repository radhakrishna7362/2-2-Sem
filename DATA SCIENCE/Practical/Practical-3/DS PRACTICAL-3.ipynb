# %% [markdown]
# **NAME: NERELLA VENKATA RADHAKRISHNA**
#
# **ID: 190031187**
#
# **PRACTICAL-3**

# %%
import pandas as pd
import numpy as np

# %%
#1
#Importing Data From a CSV file
csvfile=pd.read_csv('housing.csv')
csvfile
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#1
#Importing Data From a delimited text file (like TSV)
tsvfile=pd.read_table('housing.csv')
tsvfile
# Out:
#       longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value,ocean_proximity
# 0      -122.23,37.88,41,880,129,322,126,8.3252,452600...
# 1      -122.22,37.86,21,7099,1106,2401,1138,8.3014,35...
# 2      -122.24,37.85,52,1467,190,496,177,7.2574,35210...
# 3      -122.25,37.85,52,1274,235,558,219,5.6431,34130...
# 4      -122.25,37.85,52,1627,280,565,259,3.8462,34220...
# ...                                                  ...
# 20635  -121.09,39.48,25,1665,374,845,330,1.5603,78100...
# 20636  -121.21,39.49,18,697,150,356,114,2.5568,77100,...
# 20637  -121.22,39.43,17,2254,485,1007,433,1.7,92300,I...
# 20638  -121.32,39.43,18,1860,409,741,349,1.8672,84700...
# 20639  -121.24,39.37,16,2785,616,1387,530,2.3886,8940...
#
# [20640 rows x 1 columns]

# %%
#1
#Importing Data From an Excel file
exfile=pd.read_excel(r'houseexcel.xlsx')
exfile
# Out:
#     total_rooms  total_bedrooms  ...  median_house_value  ocean_proximity
# 0           880             129  ...              452600         NEAR BAY
# 1          7099            1106  ...              358500         NEAR BAY
# 2          1467             190  ...              352100         NEAR BAY
# 3          1274             235  ...              341300         NEAR BAY
# 4          1627             280  ...              342200         NEAR BAY
# 5           919             213  ...              269700         NEAR BAY
# 6          2535             489  ...              299200         NEAR BAY
# 7          3104             687  ...              241400         NEAR BAY
# 8          2555             665  ...              226700         NEAR BAY
# 9          3549             707  ...              261100         NEAR BAY
# 10         2202             434  ...              281500         NEAR BAY
# 11         3503             752  ...              241800         NEAR BAY
# ...

# %%
#1
#Importing Data  from a JSON formatted string
jsonfile=pd.read_json('housejson.json')
jsonfile
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#2
#Viewing/Inspecting Data
csvfile.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  20640.000000  20640.000000  ...   20640.000000        20640.000000
# mean    -119.569704     35.631861  ...       3.870671       206855.816909
# std        2.003532      2.135952  ...       1.899822       115395.615874
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.800000     33.930000  ...       2.563400       119600.000000
# 50%     -118.490000     34.260000  ...       3.534800       179700.000000
# 75%     -118.010000     37.710000  ...       4.743250       264725.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
#2
#Viewing/Inspecting Data
csvfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
#2
#Viewing/Inspecting Data
csvfile.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...              452600         NEAR BAY
# 1    -122.22     37.86  ...              358500         NEAR BAY
# 2    -122.24     37.85  ...              352100         NEAR BAY
# 3    -122.25     37.85  ...              341300         NEAR BAY
# 4    -122.25     37.85  ...              342200         NEAR BAY
#
# [5 rows x 10 columns]

# %%
#2
#Viewing/Inspecting Data
csvfile.tail()
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [5 rows x 10 columns]

# %%
#2
#Viewing/Inspecting Data
#Apply
csvfile.apply(pd.Series.value_counts)
# Out:
#             longitude  latitude  ...  median_house_value  ocean_proximity
# -124.35           1.0       NaN  ...                 NaN              NaN
# -124.3            2.0       NaN  ...                 NaN              NaN
# -124.27           1.0       NaN  ...                 NaN              NaN
# -124.26           1.0       NaN  ...                 NaN              NaN
# -124.25           1.0       NaN  ...                 NaN              NaN
# ...               ...       ...  ...                 ...              ...
# <1H OCEAN         NaN       NaN  ...                 NaN           9136.0
# INLAND            NaN       NaN  ...                 NaN           6551.0
# ISLAND            NaN       NaN  ...                 NaN              5.0
# NEAR BAY          NaN       NaN  ...                 NaN           2290.0
# NEAR OCEAN        NaN       NaN  ...                 NaN           2658.0
#
# [24864 rows x 10 columns]

# %%
#3
#Glimpse
#slicing
csvfile.loc[1:8,'Longitude':'total_rooms']
# Out:
#    Longitude  Latitude  housing_median_age  total_rooms
# 1    -122.22     37.86                  21         7099
# 2    -122.24     37.85                  52         1467
# 3    -122.25     37.85                  52         1274
# 4    -122.25     37.85                  52         1627
# 5    -122.25     37.85                  52          919
# 6    -122.25     37.84                  52         2535
# 7    -122.25     37.84                  52         3104
# 8    -122.26     37.84                  42         2555

# %%
#3
#Data Cleaning
#unique
csvfile.households.unique()
# Out:
# array([ 126, 1138,  177, ..., 1767, 1832, 1818])

# %%
#3 
#Data Cleaning
#select (First Row)
csvfile.iloc[0,:]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
#3
#Data Cleaning
#select (By position)
csvfile.iloc[0,:5]
# Out:
# longitude            -122.23
# latitude               37.88
# housing_median_age        41
# total_rooms              880
# total_bedrooms           129
# Name: 0, dtype: object

# %%
#3
#Data Cleaning
#select (By Index)
csvfile.loc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
#3
#Data Cleaning
#list
csvfile.values.tolist()
# Out:
# [[-122.23, 37.88, 41, 880, 129.0, 322, 126, 8.3252, 452600, 'NEAR BAY'],
#  [-122.22, 37.86, 21, 7099, 1106.0, 2401, 1138, 8.3014, 358500, 'NEAR BAY'],
#  [-122.24, 37.85, 52, 1467, 190.0, 496, 177, 7.2574, 352100, 'NEAR BAY'],
#  [-122.25, 37.85, 52, 1274, 235.0, 558, 219, 5.6431, 341300, 'NEAR BAY'],
#  [-122.25, 37.85, 52, 1627, 280.0, 565, 259, 3.8462, 342200, 'NEAR BAY'],
#  [-122.25, 37.85, 52, 919, 213.0, 413, 193, 4.0368, 269700, 'NEAR BAY'],
#  [-122.25, 37.84, 52, 2535, 489.0, 1094, 514, 3.6591, 299200, 'NEAR BAY'],
#  [-122.25, 37.84, 52, 3104, 687.0, 1157, 647, 3.12, 241400, 'NEAR BAY'],
#  [-122.26, 37.84, 42, 2555, 665.0, 1206, 595, 2.0804, 226700, 'NEAR BAY'],
#  [-122.25, 37.84, 52, 3549, 707.0, 1551, 714, 3.6912, 261100, 'NEAR BAY'],
#  [-122.26, 37.85, 52, 2202, 434.0, 910, 402, 3.2031, 281500, 'NEAR BAY'],
#  [-122.26, 37.85, 52, 3503, 752.0, 1504, 734, 3.2705, 241800, 'NEAR BAY'],
#  [-122.26, 37.85, 52, 2491, 474.0, 1098, 468, 3.075, 213500, 'NEAR BAY'],
# ...

# %%
#3
#Data Cleaning
#Selective renaming
csvfile.rename(columns={'housing_median_age':'Housing_Median_Age'},inplace=True)
csvfile
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#3
#Data Cleaning
#Mass renaming of columns
csvfile.rename(columns={'latitude':'Latitude','longitude':'Longitude'},inplace=True)
csvfile
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#3
#Mass renaming of index
csvfile.rename(index=lambda x:x+1)
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 1        -122.23     37.88  ...              452600         NEAR BAY
# 2        -122.22     37.86  ...              358500         NEAR BAY
# 3        -122.24     37.85  ...              352100         NEAR BAY
# 4        -122.25     37.85  ...              341300         NEAR BAY
# 5        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20636    -121.09     39.48  ...               78100           INLAND
# 20637    -121.21     39.49  ...               77100           INLAND
# 20638    -121.22     39.43  ...               92300           INLAND
# 20639    -121.32     39.43  ...               84700           INLAND
# 20640    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#3
#Change the index
csvfile.rename(index={0:"x",1:"y",2:"z"})
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# x        -122.23     37.88  ...              452600         NEAR BAY
# y        -122.22     37.86  ...              358500         NEAR BAY
# z        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#4
#Filter
csvfile[csvfile['households']>150]
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# 5        -122.25     37.85  ...              269700         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20634    -121.56     39.27  ...              116800           INLAND
# 20635    -121.09     39.48  ...               78100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [19218 rows x 10 columns]

# %%
#4
#Sort (By a Column)
csvfile.sort_values('Longitude')
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 2655     -124.35     40.54  ...               94600       NEAR OCEAN
# 1861     -124.30     41.84  ...              103600       NEAR OCEAN
# 1851     -124.30     41.80  ...               85800       NEAR OCEAN
# 2631     -124.27     40.69  ...               79000       NEAR OCEAN
# 2653     -124.26     40.58  ...              111400       NEAR OCEAN
# ...          ...       ...  ...                 ...              ...
# 12450    -114.56     33.69  ...               85700           INLAND
# 2780     -114.55     32.80  ...               56100           INLAND
# 12447    -114.49     33.97  ...               87500           INLAND
# 13923    -114.47     34.40  ...               80100           INLAND
# 13924    -114.31     34.19  ...               66900           INLAND
#
# [20640 rows x 10 columns]

# %%
#4
#Sort (By a Column) Descending Order
csvfile.sort_values('Longitude',ascending=False)
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 13924    -114.31     34.19  ...               66900           INLAND
# 13923    -114.47     34.40  ...               80100           INLAND
# 12447    -114.49     33.97  ...               87500           INLAND
# 2780     -114.55     32.80  ...               56100           INLAND
# 12450    -114.56     33.69  ...               85700           INLAND
# ...          ...       ...  ...                 ...              ...
# 2653     -124.26     40.58  ...              111400       NEAR OCEAN
# 2631     -124.27     40.69  ...               79000       NEAR OCEAN
# 1851     -124.30     41.80  ...               85800       NEAR OCEAN
# 1861     -124.30     41.84  ...              103600       NEAR OCEAN
# 2655     -124.35     40.54  ...               94600       NEAR OCEAN
#
# [20640 rows x 10 columns]

# %%
#4
#GroupBy
csvfile.groupby("total_rooms")
csvfile
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#4
#GroupBy
csvfile.groupby(["total_rooms","total_bedrooms"])
csvfile
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...              452600         NEAR BAY
# 1        -122.22     37.86  ...              358500         NEAR BAY
# 2        -122.24     37.85  ...              352100         NEAR BAY
# 3        -122.25     37.85  ...              341300         NEAR BAY
# 4        -122.25     37.85  ...              342200         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...               78100           INLAND
# 20636    -121.21     39.49  ...               77100           INLAND
# 20637    -121.22     39.43  ...               92300           INLAND
# 20638    -121.32     39.43  ...               84700           INLAND
# 20639    -121.24     39.37  ...               89400           INLAND
#
# [20640 rows x 10 columns]

# %%
#4
#pivot_table
csvfile.pivot_table(index="total_rooms",values=["total_bedrooms","population"],aggfunc=np.sum)
# Out:
#              population  total_bedrooms
# total_rooms
# 2                     6             2.0
# 6                     8             2.0
# 8                    13             1.0
# 11                   24            11.0
# 12                   18             4.0
# ...                 ...             ...
# 30450              9419          5033.0
# 32054             15507          5290.0
# 32627             28566          6445.0
# 37937             16122          5471.0
# 39320             16305          6210.0
#
# [5926 rows x 2 columns]

# %%
#5
#Perform Exploratory Data Analysis
csvfile.sample(8)
# Out:
#        Longitude  Latitude  ...  median_house_value  ocean_proximity
# 14324    -117.15     32.72  ...              137500       NEAR OCEAN
# 6227     -117.93     34.06  ...              202800        <1H OCEAN
# 12209    -117.02     33.60  ...              337200           INLAND
# 1158     -121.53     39.53  ...               91200           INLAND
# 4012     -118.60     34.16  ...              313100        <1H OCEAN
# 14842    -117.08     32.69  ...              117000       NEAR OCEAN
# 9911     -122.28     38.31  ...              166700         NEAR BAY
# 15162    -117.03     32.96  ...              182100        <1H OCEAN
#
# [8 rows x 10 columns]
