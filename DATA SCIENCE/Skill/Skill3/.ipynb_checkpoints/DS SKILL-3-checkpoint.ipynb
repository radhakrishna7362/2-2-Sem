# %% [markdown]
# **NAME: NERELLA VENKATA RADHAKRISHNA**
#
# **ID: 190031187**
#
# **SKILL-3**

# %%
import pandas as pd
import numpy as np

# %%
#1 
#Loading data & cleaning
df = pd.read_csv('Hospital General Information.csv',encoding="ISO-8859-1")
df
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %%
#1 
#Loading data & cleaning
df.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         143
# Hospital overall rating                                             0
# ...

# %%
#1 
#Loading data & cleaning
df.notnull()
# Out:
#       Provider ID  Hospital Name  Address  City  State  ZIP Code  County Name  \
# 0            True           True     True  True   True      True         True
# 1            True           True     True  True   True      True         True
# 2            True           True     True  True   True      True         True
# 3            True           True     True  True   True      True         True
# 4            True           True     True  True   True      True         True
# ...           ...            ...      ...   ...    ...       ...          ...
# 4807         True           True     True  True   True      True         True
# 4808         True           True     True  True   True      True        False
# 4809         True           True     True  True   True      True        False
# 4810         True           True     True  True   True      True        False
# 4811         True           True     True  True   True      True        False
#
# ...

# %%
#2
#Hospital Analysis-‘Hospital Type’ by ‘Ownership’
hospital_analysis=df.groupby(['Hospital Ownership','Hospital Type']).size()
hospital_analysis
# Out:
# Hospital Ownership                           Hospital Type
# Government - Federal                         Acute Care Hospitals           37
#                                              Critical Access Hospitals       8
# Government - Hospital District or Authority  Acute Care Hospitals          273
#                                              Childrens                       1
#                                              Critical Access Hospitals     287
# Government - Local                           Acute Care Hospitals          176
#                                              Critical Access Hospitals     231
# Government - State                           Acute Care Hospitals           50
#                                              Childrens                       3
#                                              Critical Access Hospitals      12
# Physician                                    Acute Care Hospitals           65
# ...

# %%
#3
#Total number of Hospitals in each ‘State’
no_of_hospitals=df.groupby(['State']).size()
no_of_hospitals
# Out:
# State
# AK     22
# AL     90
# AR     75
# AS      1
# AZ     80
# CA    343
# CO     78
# CT     31
# DC      8
# DE      7
# FL    187
# GA    133
# GU      2
# HI     23
# IA    116
# ID     41
# IL    180
# IN    120
# KS    137
# KY     94
# LA    121
# MA     64
# MD     49
# ME     33
# MI    131
# MN    131
# MO    112
# MP      1
# MS     95
# MT     62
# NC    107
# ND     44
# NE     89
# NH     26
# NJ     66
# NM     41
# NV     35
# NY    171
# OH    168
# OK    124
# OR     60
# PA    171
# PR     52
# RI     11
# SC     60
# SD     60
# TN    107
# TX    411
# UT     46
# VA     86
# VI      2
# VT     14
# WA     91
# WI    126
# WV     49
# WY     28
# dtype: int64

# %%
#4
#Country wise hospital numbers in ‘TX’
country_wise=df[df['State']=='TX']
country_wise
# Out:
#       Provider ID                        Hospital Name  \
# 3954       450002         PROVIDENCE MEMORIAL HOSPITAL
# 3955       450007     PETERSON REGIONAL MEDICAL CENTER
# 3956       450010   UNITED REGIONAL HEALTH CARE SYSTEM
# 3957       450011     ST JOSEPH REGIONAL HEALTH CENTER
# 3958       450015  PARKLAND HEALTH AND HOSPITAL SYSTEM
# ...           ...                                  ...
# 4803       670114                WEIMAR MEDICAL CENTER
# 4804       670115         CLEVELAND EMERGENCY HOSPTIAL
# 4805       670116                   WISE HEALTH SYSTEM
# 4806       670117     TEXAS GENERAL HOSPITAL- VZRMC LP
# 4807       670118                 FIRST TEXAS HOSPITAL
#
#                          Address           City State  ZIP Code County Name  \
# 3954            2001 N OREGON ST        EL PASO    TX     79902     EL PASO
# 3955      551 HILL COUNTRY DRIVE      KERRVILLE    TX     78028        KERR
# ...

# %%
#5
#Distribution of ‘Hospital Type’ and ‘Ownership in Texas’
ownership_texas=df[['State','Hospital Ownership']]
ownership_texas=ownership_texas[ownership_texas['State']=='TX']
ownership_texas
# Out:
#      State                           Hospital Ownership
# 3954    TX                                  Proprietary
# 3955    TX               Voluntary non-profit - Private
# 3956    TX               Voluntary non-profit - Private
# 3957    TX               Voluntary non-profit - Private
# 3958    TX  Government - Hospital District or Authority
# ...    ...                                          ...
# 4803    TX                                  Proprietary
# 4804    TX                                  Proprietary
# 4805    TX  Government - Hospital District or Authority
# 4806    TX                                  Proprietary
# 4807    TX                                  Proprietary
#
# [411 rows x 2 columns]

# %%
#6
#Find ‘Timeliness of care national comparison footnote’ and its ‘hospital’
timeliness=pd.crosstab(df['Hospital Name'],df['Timeliness of care national comparison footnote']=="Above the national average")
timeliness
# Out:
# Timeliness of care national comparison footnote  False
# Hospital Name
# ABBEVILLE AREA MEDICAL CENTER                        1
# ABBEVILLE GENERAL HOSPITAL                           1
# ABBOTT NORTHWESTERN HOSPITAL                         1
# ABILENE REGIONAL MEDICAL CENTER                      1
# ABINGTON MEMORIAL HOSPITAL                           1
# ...                                                ...
# YORK HOSPITAL                                        2
# YUKON KUSKOKWIM DELTA REG HOSPITAL                   1
# YUMA DISTRICT HOSPITAL                               1
# YUMA REGIONAL MEDICAL CENTER                         1
# ZUNI COMPREHENSIVE COMMUNITY HEALTH CENTER           1
#
# [4623 rows x 1 columns]

# %%
#7
#‘Hospital rating’
hospital_rating=df[['Hospital Type','Hospital overall rating']]
hospital_rating
# Out:
#              Hospital Type Hospital overall rating
# 0     Acute Care Hospitals                       3
# 1     Acute Care Hospitals                       3
# 2     Acute Care Hospitals                       2
# 3     Acute Care Hospitals                       2
# 4     Acute Care Hospitals                       3
# ...                    ...                     ...
# 4807  Acute Care Hospitals           Not Available
# 4808  Acute Care Hospitals           Not Available
# 4809  Acute Care Hospitals                       3
# 4810  Acute Care Hospitals           Not Available
# 4811  Acute Care Hospitals           Not Available
#
# [4812 rows x 2 columns]

# %%
#8
#Find ‘Acute Care Hospitals’ with rating (4) along with ’state’
df.loc[(df['Hospital overall rating']=="4") & (df['Hospital Type']=="Acute Care Hospitals"),['State']]
# Out:
#      State
# 10      AL
# 11      AL
# 14      AL
# 15      AL
# 17      AL
# ...    ...
# 4777    TX
# 4779    TX
# 4780    TX
# 4782    TX
# 4784    TX
#
# [724 rows x 1 columns]

# %%
#9
#Which type of hospitals has highest ‘Non-availability’ of ‘Safety of Care data’
res=df.loc[(df["Safety of care national comparison"]=="Not Available"),["Hospital Type"]]
res.mode()
# Out:
#                Hospital Type
# 0  Critical Access Hospitals

# %%
#10
#What are the different types of ‘Patient experience national comparison’ and list their ‘Provider ID’
df.groupby(["Patient experience national comparison","Provider ID"]).size()
# Out:
# Patient experience national comparison  Provider ID
# Above the national average              10021          1
#                                         10022          1
#                                         10029          1
#                                         10033          1
#                                         10044          1
#                                                       ..
# Same as the national average            670023         1
#                                         670044         1
#                                         670047         1
#                                         670085         1
#                                         670106         1
# Length: 4812, dtype: int64
